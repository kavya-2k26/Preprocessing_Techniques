# %%
import pickle

# %%
x_scaler = pickle.load(open("x_scaler.pkl","rb"))
y_scaler = pickle.load(open("y_scaler.pkl","rb"))

# %%
preinput=x_scaler.transform([[1300,12000,4000,0,1]])
# Out:
# C:\Users\kavya\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
preinput
# Out:
# array([[-1.46755405, -4.33835385, -1.50744257, -0.5       ,  1.30088727]])

# %%
loaded_model=pickle.load(open("finalized_model_svr.sav",'rb'))
result=loaded_model.predict(preinput)

# %%
result
# Out:
# array([-1.03109284])

# %%
preoutput=y_scaler.inverse_transform([result])

# %%
preoutput
# Out:
# array([[65875.16964031]])
